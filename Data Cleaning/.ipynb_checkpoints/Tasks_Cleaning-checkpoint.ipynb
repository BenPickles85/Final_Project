# %%
# Import Dependencies
import os
import csv
import pandas as pd
import numpy as np

# %%
# Import CSV, read into pandas and display head
tasks_file = "../Resources/Novus_Daily_Tasks.xls"
overdue_tasks_df = pd.read_excel(tasks_file, sheet_name="Overdue_List")
overdue_tasks_df.head(20)
# Out:
#                                     X C H A N G I N G            Unnamed: 1  \
# 0   Tasks OVERDUE Report - Detailed List (Due on o...                   NaN
# 1                                                 NaN                   NaN
# 2                             Fex/Pgm Name : dcmg0100                   NaN
# 3                               Run Date : 14/01/2022                   NaN
# 4                           Refresh Date : 13/01/2022                   NaN
# 5                                                 NaN                   NaN
# 6                                          \n\n\nTeam  \n\nAcction\nUser-ID
# 7                                                  A1               A08????
# 8                                                  A1               A08????
# 9                                                  A1               A08????
# 10                                                 A1               A08????
# ...

# %%
overdue_tasks_df = overdue_tasks_df.drop([0,1,2,3,4,5])
overdue_tasks_df.head()
# Out:
#    X C H A N G I N G            Unnamed: 1  \
# 6         \n\n\nTeam  \n\nAcction\nUser-ID
# 7                 A1               A08????
# 8                 A1               A08????
# 9                 A1               A08????
# 10                A1               A08????
#
#                                Unnamed: 2  \
# 6                      \nTask\nRole\nName
# 7   10617_RETURN TO WORK CLAIMS PROCESSOR
# 8   10617_RETURN TO WORK CLAIMS PROCESSOR
# 9   10617_RETURN TO WORK CLAIMS PROCESSOR
# 10  10617_RETURN TO WORK CLAIMS PROCESSOR
#
#                                   Unnamed: 3   Unnamed: 4  \
# 6                             \n\nTask\nName  \n\n\nClaim
# 7                CRT: Certificate Registered  08210030378
# 8   CRT: Process Weekly Compensation Payment  08210032211
# 9                     CRT: Query Certificate  08210011575
# 10                 DOC: Claim Administration  08190061564
#
#              Unnamed: 5           Unnamed: 6          Unnamed: 7  \
# ...

# %%
overdue_tasks_df.columns=overdue_tasks_df.iloc[0]
overdue_tasks_df
# Out:
# 6     \n\n\nTeam  \n\nAcction\nUser-ID  \
# 6     \n\n\nTeam  \n\nAcction\nUser-ID
# 7             A1               A08????
# 8             A1               A08????
# 9             A1               A08????
# 10            A1               A08????
# ...          ...                   ...
# 3963          DH               A08C048
# 3964          DH               A08C048
# 3965          DH               A08C048
# 3966          DH               A08C048
# 3967          DH               A08C048
#
# 6                                 \nTask\nRole\nName  \
# 6                                 \nTask\nRole\nName
# 7              10617_RETURN TO WORK CLAIMS PROCESSOR
# 8              10617_RETURN TO WORK CLAIMS PROCESSOR
# 9              10617_RETURN TO WORK CLAIMS PROCESSOR
# 10             10617_RETURN TO WORK CLAIMS PROCESSOR
# ...                                              ...
# 3963  THOMAS ALYSSA_9485_RETURN TO WORK CASE MANAGER
# 3964  THOMAS ALYSSA_9485_RETURN TO WORK CASE MANAGER
# ...

# %%
overdue_tasks_df=overdue_tasks_df.drop([6])
overdue_tasks_df.head()
# Out:
# 6   \n\n\nTeam  \n\nAcction\nUser-ID                     \nTask\nRole\nName  \
# 6   \n\n\nTeam  \n\nAcction\nUser-ID                     \nTask\nRole\nName
# 7           A1               A08????  10617_RETURN TO WORK CLAIMS PROCESSOR
# 8           A1               A08????  10617_RETURN TO WORK CLAIMS PROCESSOR
# 9           A1               A08????  10617_RETURN TO WORK CLAIMS PROCESSOR
# 10          A1               A08????  10617_RETURN TO WORK CLAIMS PROCESSOR
#
# 6                             \n\nTask\nName  \n\n\nClaim  \
# 6                             \n\nTask\nName  \n\n\nClaim
# 7                CRT: Certificate Registered  08210030378
# 8   CRT: Process Weekly Compensation Payment  08210032211
# 9                     CRT: Query Certificate  08210011575
# 10                 DOC: Claim Administration  08190061564
#
# 6    \n\nCreation\nDate       \n\nDue \nDate  \n\nDays \nOverdue  \
# 6    \n\nCreation\nDate       \n\nDue \nDate  \n\nDays \nOverdue
# ...
